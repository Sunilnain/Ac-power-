# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # importing Dataset

# %%
data=pd.read_csv("AC_data.csv")

# %%
data
# Out:
#                          0      AC 1      AC 2      AC 3      AC 4      AC 5  \
# 0      2019-08-01 00:00:00  7.518632  8.788315  0.000000  0.000000  2.617045
# 1      2019-08-01 00:01:00       NaN       NaN       NaN       NaN       NaN
# 2      2019-08-01 00:02:00  7.426114  8.940615  0.000000  0.000000  2.581625
# 3      2019-08-01 00:03:00       NaN       NaN       NaN       NaN       NaN
# 4      2019-08-01 00:04:00  7.052986  9.161103  0.000000  0.000000  2.592095
# ...                    ...       ...       ...       ...       ...       ...
# 87835  2019-09-30 23:55:00  0.000000  6.122385  2.192198  2.083315  1.046250
# 87836  2019-09-30 23:56:00       NaN       NaN       NaN       NaN       NaN
# 87837  2019-09-30 23:57:00  1.209176  6.152532  2.211421  0.000000  1.448103
# 87838  2019-09-30 23:58:00       NaN       NaN       NaN       NaN       NaN
# 87839  2019-09-30 23:59:00  1.430442  6.078281  1.891162  0.000000  1.577491
#
# ...

# %% [markdown]
# Handling Missing Data

# %%
data.isnull().sum()
# Out:
# 0            0
# AC 1     44132
# AC 2     44129
# AC 3     44127
# AC 4     44136
# AC 5     44124
# AC 6     44123
# AC 7     44161
# AC 8     44136
# AC 9     44186
# AC 10    44150
# AC 11    44170
# AC 12    44127
# AC 13    44121
# AC 14    44144
# AC 15    44125
# AC 16    44130
# AC 17    44126
# AC 18    44117
# dtype: int64

# %%
data.dropna(inplace=True) #drop all null values

# %%
data.isnull().sum()
# Out:
# 0        0
# AC 1     0
# AC 2     0
# AC 3     0
# AC 4     0
# AC 5     0
# AC 6     0
# AC 7     0
# AC 8     0
# AC 9     0
# AC 10    0
# AC 11    0
# AC 12    0
# AC 13    0
# AC 14    0
# AC 15    0
# AC 16    0
# AC 17    0
# AC 18    0
# dtype: int64

# %%
data.shape
# Out:
# (34642, 19)

# %%
data.head()
# Out:
#                      0      AC 1      AC 2  AC 3  AC 4      AC 5      AC 6  \
# 0  2019-08-01 00:00:00  7.518632  8.788315   0.0   0.0  2.617045  4.079041
# 2  2019-08-01 00:02:00  7.426114  8.940615   0.0   0.0  2.581625  3.781231
# 4  2019-08-01 00:04:00  7.052986  9.161103   0.0   0.0  2.592095  3.800127
# 6  2019-08-01 00:06:00  6.665446  9.065626   0.0   0.0  2.575639  3.772891
# 8  2019-08-01 00:08:00  6.674838  9.096130   0.0   0.0  2.021472  3.155697
#
#        AC 7      AC 8      AC 9     AC 10     AC 11     AC 12     AC 13  \
# 0  2.782276  4.624447  5.222060  2.151238  1.585072  0.560373  3.142941
# 2  2.529366  5.057423  5.349465  2.414715  2.168184  1.818730  3.085110
# 4  2.332304  6.322521  3.995392  2.237114  3.345624  2.310409  3.132799
# 6  2.596200  5.805132  3.553778  1.878356  2.737645  2.510972  3.090007
# 8  2.845417  6.315060  3.042244  1.914650  2.452500  2.171791  3.097202
#
#       AC 14     AC 15     AC 16     AC 17     AC 18
# ...

# %%
data1=data.drop("0",axis=1) # creating another copy of data

# %%
data1
# Out:
#            AC 1      AC 2      AC 3      AC 4      AC 5      AC 6      AC 7  \
# 0      7.518632  8.788315  0.000000  0.000000  2.617045  4.079041  2.782276
# 2      7.426114  8.940615  0.000000  0.000000  2.581625  3.781231  2.529366
# 4      7.052986  9.161103  0.000000  0.000000  2.592095  3.800127  2.332304
# 6      6.665446  9.065626  0.000000  0.000000  2.575639  3.772891  2.596200
# 8      6.674838  9.096130  0.000000  0.000000  2.021472  3.155697  2.845417
# ...         ...       ...       ...       ...       ...       ...       ...
# 87831  0.000000  6.089533  2.322677  1.422932  0.000000  0.000000  3.729901
# 87833  0.000000  6.046765  2.195754  1.861175  0.813454  0.000000  3.666080
# 87835  0.000000  6.122385  2.192198  2.083315  1.046250  0.000000  3.668421
# 87837  1.209176  6.152532  2.211421  0.000000  1.448103  0.000000  3.151248
# 87839  1.430442  6.078281  1.891162  0.000000  1.577491  4.364239  3.126339
#
# ...

# %% [markdown]
# # Identifying Maximum & Minimum used AC

# %%
data1.loc['Total'] = data1.sum()
data1
# Out:
#                AC 1           AC 2          AC 3          AC 4          AC 5  \
# 0          7.518632       8.788315      0.000000      0.000000      2.617045
# 2          7.426114       8.940615      0.000000      0.000000      2.581625
# 4          7.052986       9.161103      0.000000      0.000000      2.592095
# 6          6.665446       9.065626      0.000000      0.000000      2.575639
# 8          6.674838       9.096130      0.000000      0.000000      2.021472
# ...             ...            ...           ...           ...           ...
# 87833      0.000000       6.046765      2.195754      1.861175      0.813454
# 87835      0.000000       6.122385      2.192198      2.083315      1.046250
# 87837      1.209176       6.152532      2.211421      0.000000      1.448103
# 87839      1.430442       6.078281      1.891162      0.000000      1.577491
# Total  82936.044911  134136.090605  86767.765132  80136.762231  50800.569898
#
# ...

# %%
data1.loc['Total'].max() # calculate maximum power consumed AC
# Out:
# 223573.07607886364

# %% [markdown]
# AC 18 was maximum used.

# %%
data1.loc['Total'].min()# calculate minimum power consumed AC
# Out:
# 50800.56989750784

# %% [markdown]
# AC 5 was minimum used.

# %%
data["0"]=pd.to_datetime(data['0'])

# %%
data.rename(columns={'0':"Date-Time"},inplace=True)

# %%
data
# Out:
#                 Date-Time      AC 1      AC 2      AC 3      AC 4      AC 5  \
# 0     2019-08-01 00:00:00  7.518632  8.788315  0.000000  0.000000  2.617045
# 2     2019-08-01 00:02:00  7.426114  8.940615  0.000000  0.000000  2.581625
# 4     2019-08-01 00:04:00  7.052986  9.161103  0.000000  0.000000  2.592095
# 6     2019-08-01 00:06:00  6.665446  9.065626  0.000000  0.000000  2.575639
# 8     2019-08-01 00:08:00  6.674838  9.096130  0.000000  0.000000  2.021472
# ...                   ...       ...       ...       ...       ...       ...
# 87831 2019-09-30 23:51:00  0.000000  6.089533  2.322677  1.422932  0.000000
# 87833 2019-09-30 23:53:00  0.000000  6.046765  2.195754  1.861175  0.813454
# 87835 2019-09-30 23:55:00  0.000000  6.122385  2.192198  2.083315  1.046250
# 87837 2019-09-30 23:57:00  1.209176  6.152532  2.211421  0.000000  1.448103
# 87839 2019-09-30 23:59:00  1.430442  6.078281  1.891162  0.000000  1.577491
#
# ...

# %%
data.dtypes
# Out:
# Date-Time    datetime64[ns]
# AC 1                float64
# AC 2                float64
# AC 3                float64
# AC 4                float64
# AC 5                float64
# AC 6                float64
# AC 7                float64
# AC 8                float64
# AC 9                float64
# AC 10               float64
# AC 11               float64
# AC 12               float64
# AC 13               float64
# AC 14               float64
# AC 15               float64
# AC 16               float64
# AC 17               float64
# AC 18               float64
# dtype: object

# %%
data=data.set_index('Date-Time') # making 'date-time' column as index

# %%
data
# Out:
#                          AC 1      AC 2      AC 3      AC 4      AC 5  \
# Date-Time
# 2019-08-01 00:00:00  7.518632  8.788315  0.000000  0.000000  2.617045
# 2019-08-01 00:02:00  7.426114  8.940615  0.000000  0.000000  2.581625
# 2019-08-01 00:04:00  7.052986  9.161103  0.000000  0.000000  2.592095
# 2019-08-01 00:06:00  6.665446  9.065626  0.000000  0.000000  2.575639
# 2019-08-01 00:08:00  6.674838  9.096130  0.000000  0.000000  2.021472
# ...                       ...       ...       ...       ...       ...
# 2019-09-30 23:51:00  0.000000  6.089533  2.322677  1.422932  0.000000
# 2019-09-30 23:53:00  0.000000  6.046765  2.195754  1.861175  0.813454
# 2019-09-30 23:55:00  0.000000  6.122385  2.192198  2.083315  1.046250
# 2019-09-30 23:57:00  1.209176  6.152532  2.211421  0.000000  1.448103
# 2019-09-30 23:59:00  1.430442  6.078281  1.891162  0.000000  1.577491
#
#                          AC 6      AC 7      AC 8      AC 9     AC 10  \
# Date-Time
# ...

# %% [markdown]
# # Correlation b/t the data

# %%
plt.figure(figsize = (12,8))
sns.heatmap(data.corr(), annot=True)

# %% [markdown]
# # Plotting between date-time & AC's power consumptions

# %%
plt.rcParams['figure.figsize']=[12.0,8.0]
from datetime import datetime
start_date=datetime(2019,9,29)
end_date=datetime(2019,9,30)
data[(start_date<=data.index) & (data.index<=end_date)].plot(grid=True)

# %%
data.sort_index(inplace=True)

# %% [markdown]
# # Decomposition of AC-18

# %% [markdown]
# # Finding Trend and Seasonal of Maximum used AC (AC-18) from Date 2019-08-01 to 2019-09-30

# %%
import statsmodels.api as sm
decomposition=sm.tsa.seasonal_decompose(data["AC 18"],model='additive',extrapolate_trend='freq', period=1)
fig=decomposition.plot()
plt.rcParams['figure.figsize']=[9.0,5.0]

# %% [markdown]
# # Finding Trend and Seasonal of Minimum used AC (AC-05) from Date 2019-08-01 to 2019-09-30

# %%
import statsmodels.api as sm
decomposition=sm.tsa.seasonal_decompose(data["AC 5"],model='additive',extrapolate_trend='freq', period=1)
fig=decomposition.plot()
plt.rcParams['figure.figsize']=[9.0,5.0]

# %% [markdown]
# # Importing another dataset of temperature of Gurugram

# %%
temp=pd.read_excel("temp.xlsx")

# %%
temp
# Out:
#        maxtempC  mintempC
# 0            20         8
# 1            20         8
# 2            20         8
# 3            20         8
# 4            20         8
# ...         ...       ...
# 34637        19        10
# 34638        19        10
# 34639        19        10
# 34640        19        10
# 34641        19        10
#
# [34642 rows x 2 columns]

# %%
temp.isnull().sum()
# Out:
# maxtempC    0
# mintempC    0
# dtype: int64

# %%
data["temp"]=temp["maxtempC"].values # add temp data into original data

# %%
data
# Out:
#                          AC 1      AC 2      AC 3      AC 4      AC 5  \
# Date-Time
# 2019-08-01 00:00:00  7.518632  8.788315  0.000000  0.000000  2.617045
# 2019-08-01 00:02:00  7.426114  8.940615  0.000000  0.000000  2.581625
# 2019-08-01 00:04:00  7.052986  9.161103  0.000000  0.000000  2.592095
# 2019-08-01 00:06:00  6.665446  9.065626  0.000000  0.000000  2.575639
# 2019-08-01 00:08:00  6.674838  9.096130  0.000000  0.000000  2.021472
# ...                       ...       ...       ...       ...       ...
# 2019-09-30 23:51:00  0.000000  6.089533  2.322677  1.422932  0.000000
# 2019-09-30 23:53:00  0.000000  6.046765  2.195754  1.861175  0.813454
# 2019-09-30 23:55:00  0.000000  6.122385  2.192198  2.083315  1.046250
# 2019-09-30 23:57:00  1.209176  6.152532  2.211421  0.000000  1.448103
# 2019-09-30 23:59:00  1.430442  6.078281  1.891162  0.000000  1.577491
#
#                          AC 6      AC 7      AC 8      AC 9     AC 10  \
# Date-Time
# ...

# %% [markdown]
# # Plotting between datetime, temp, Ac power consumption

# %%
plt.rcParams['figure.figsize']=[12.0,8.0]
data.plot(grid=True)

# %% [markdown]
# # Apply Sklearn models

# %%
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.linear_model import LinearRegression

# %%
X=data.drop(['temp'], axis=1)
y=data['temp']

# %%
X_train,X_valid,y_train,y_valid = train_test_split(X,y,test_size=0.2,random_state=22)

# %%
features= X
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression()
lr.fit(X_train, y_train)
lr_predict = lr.predict(X_valid)
# Out:
# C:\Users\sunil\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
from sklearn.metrics import accuracy_score
print("Logistic Regression Accuracy:",accuracy_score(y_valid,lr_predict))
# Out:
# Logistic Regression Accuracy: 0.12887862606436715

# %%
#RandomForestClassifier model
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier(max_depth=7, n_estimators = 500)

rf.fit(X_train,y_train)
predictions = rf.predict(X_valid)

from sklearn.metrics import accuracy_score
print("Randomforestclassification : ",accuracy_score(y_valid, predictions))
# Out:
# Randomforestclassification :  0.3045172463558955
